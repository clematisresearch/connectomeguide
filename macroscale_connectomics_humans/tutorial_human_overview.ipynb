# %% [markdown]
# ---
# title: "Tutorial Codebook (Human): Overview"
# authors:
#   - name: Sapolnach Prompiengchai
#     affiliations:
#       - University of Oxford
#   - name: Aarushi Vardhan
#     affiliations:
#       - University of Toronto / University of Cambridge
# ---

# %% [markdown]
# # Next Steps: Before Programming
#
# The remainder of this notebook series is a **hands-on coding tutorial**. From this point onwards, we will be implementing the methods discussed so far using Python, while introducing additional theoretical concepts whenever they are needed. In particular, we will cover the essential ideas behind **graph theory** and **network science**, and the **statistical methods** used to link brain measures to phenotypes.
#
# Remember, these concepts will be introduced gradually alongside practical examples, so do not worry!
#
# ## Tutorial Overview
#
# ### Tutorial 1: Visualizing Timeseries
# Learn how to load, explore, subset, and visualize resting-state fMRI timeseries data using common Python libraries. This tutorial introduces the basic structure of neuroimaging timeseries data.
#
# ### Tutorial 2: Functional Connectivity
# Learn how to calculate and visualize functional connectivity (FC) matrices from timeseries data, and save each subject's FC matrix locally for future analyses.
#
# ### Tutorial 3: Graph Theoretical Analysis of Functional Networks
# Learn the fundamentals of graph theory in neuroscience and calculate common graph theoretical measures from functional connectivity networks.
#
# ### Tutorial 4: Linking Brain and Phenotypes (Part 1: Association)
# Learn how to investigate relationships between brain measures and phenotypes using appropriate statistical methods, including group comparisons and correlation analyses.
#
# ### Tutorial 5: Linking Brain and Phenotypes (Part 2: Prediction)
# Learn the fundamentals of predicting phenotypes from brain data using machine learning techniques such as linear regression and support vector machines (SVMs).
