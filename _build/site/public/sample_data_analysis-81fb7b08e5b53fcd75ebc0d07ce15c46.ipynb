# %% [markdown]
# # Sample Data Analysis
#
# Author: Priya Shah
#
# This notebook is a starter template for a worked analysis example.

# %% [markdown]
# ## Step 1
#
# Load data and inspect the shapes.

# %%
import numpy as np
import pandas as pd

print("Ready to analyze data")
