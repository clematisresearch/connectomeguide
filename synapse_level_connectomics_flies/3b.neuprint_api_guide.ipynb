# %% [markdown]
# title: neuPrint API Guide hands on Tutorial
# authors:
#   - name: Sapolnach Prompiengchai
#     affiliations:
#       - University of Oxford
#   - name: Aarushi Vardhan
#     affiliations:
#       - University of Toronto / University of Cambridge

# %%
# 1. load your packages at the top
import pandas as pd
import plotly.express as px
from neuPrint import Client
c = Client('neuprint.janelia.org', dataset='male-cns:v1.0', token='eyJhbGciOiJIUzI1NiIsInR5cCI6IkpXVCJ9.eyJlbWFpbCI6ImFhcnVzaGkudmFyZGhhbkBnbWFpbC5jb20iLCJsZXZlbCI6Im5vYXV0aCIsImltYWdlLXVybCI6Imh0dHBzOi8vbGgzLmdvb2dsZXVzZXJjb250ZW50LmNvbS9hL0FDZzhvY0xlOVNycVUyYjl6bXZFM29wb2QyRFFLOWJlTThQRDgyT2lid25CVG01R0UtMGtWT3c9czk2LWM_c3o9NTA_c3o9NTAiLCJleHAiOjE5NjU4MTAxNTB9.lpFdEuQJ-k7toc1X7FavtQ95X-b5pgszBcv9V4zTzHI')
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[1], line 3
#       1 # 1. load your packages at the top
#       2 import pandas as pd
# ----> 3 import plotly.express as px
#       4 from neuPrint import Client
#       5 c = Client('neuprint.janelia.org', dataset='male-cns:v1.0', token='eyJhbGciOiJIUzI1NiIsInR5cCI6IkpXVCJ9.eyJlbWFpbCI6ImFhcnVzaGkudmFyZGhhbkBnbWFpbC5jb20iLCJsZXZlbCI6Im5vYXV0aCIsImltYWdlLXVybCI6Imh0dHBzOi8vbGgzLmdvb2dsZXVzZXJjb250ZW50LmNvbS9hL0FDZzhvY0xlOVNycVUyYjl6bXZFM29wb2QyRFFLOWJlTThQRDgyT2lid25CVG01R0UtMGtWT3c9czk2LWM_c3o9NTA_c3o9NTAiLCJleHAiOjE5NjU4MTAxNTB9.lpFdEuQJ-k7toc1X7FavtQ95X-b5pgszBcv9V4zTzHI')
#
# ModuleNotFoundError: No module named 'plotly'
